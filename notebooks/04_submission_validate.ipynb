# %% [markdown]
# # PARC2026 04: Submission Validate
# 最良CheckpointをオフラインRuntimeへ配置し、依存・容量・SHA256・運営Validatorを確認します。

# %%
# %cd /content/Physical_ai
# !python scripts/validate_submission_requirements.py submission

# %%
from pathlib import Path
SUBMISSION = Path('/content/Physical_ai/submission/openvla_oft_offline')
MODEL_TARGET = SUBMISSION / 'model_weights/openvla_oft_plus'
MODEL_TARGET.mkdir(parents=True, exist_ok=True)
print('Place the frozen final checkpoint at:', MODEL_TARGET)

# %%
OUTPUT = '/content/drive/MyDrive/PARC2026/60_submissions/parc2026_track1_openvla_oft_plus.zip'
# !mkdir -p /content/drive/MyDrive/PARC2026/60_submissions
# !python submission/openvla_oft_offline/tools/build_submission_zip.py --source submission/openvla_oft_offline --output {OUTPUT}
# !cat {OUTPUT}.json

# %%
OFFICIAL = '/content/PARC2026_pre'
# !test -d {OFFICIAL} && python {OFFICIAL}/validate_submission.py {OUTPUT} || echo 'Official validator repo is not present yet'
