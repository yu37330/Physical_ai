# %% [markdown]
# # PARC2026 01: Model Feasibility
# 固定OpenVLA-OFT環境、Base Checkpoint、Checkpoint Manifest、オフライン推論Runtimeを準備します。

# %%
# %cd /content/Physical_ai
# !PROJECT_ROOT=/content/Physical_ai WORKDIR=/content/openvla-oft bash training/openvla_oft_a100/scripts/bootstrap_colab.sh

# %%
MODEL_ROOT = '/content/drive/MyDrive/PARC2026/30_models/openvla_oft_plus_base'
# !mkdir -p {MODEL_ROOT}
# !python training/openvla_oft_a100/scripts/download_base_checkpoint.py --output {MODEL_ROOT}

# %%
# !OPENVLA_OFT_SOURCE=/content/openvla-oft bash submission/openvla_oft_offline/scripts/prepare_vendor.sh
# !python submission/openvla_oft_offline/tools/benchmark_runtime.py --help

# %% [markdown]
# 次にCheckpointを`submission/openvla_oft_offline/model_weights/openvla_oft_plus`へ配置し、完全オフライン状態で20回推論を実測します。
